# %% [markdown]
# Great to hear you've completed learning NumPy! 💪
# To strengthen your **logic-building and problem-solving** skills with NumPy (especially for Machine Learning), here's a **set of curated practice problems** organized by **difficulty and topic**.
#
# ---
#
# ## 🧠 NUMPY PRACTICE SET
#
# ---
#
# ### 🔹 **Beginner (Warm-up & Syntax Mastery)**
#
# Focus: Array creation, indexing, slicing, reshaping
#
# 1. **Create a null vector of size 10**
#    ➤ Replace the 5th value with 1.
#
# 2. **Create a vector with values ranging from 10 to 49**
#    ➤ Reverse it using slicing.
#
# 3. **Create a 3x3 matrix with values from 0 to 8**
#
# 4. **Find the indices of non-zero elements in**:
#    `arr = np.array([1,2,0,0,4,0])`
#
# 5. **Create a 3x3 identity matrix**
#
# 6. **Create a 1D array of 10 random numbers and sort it**
#
# ---
#
# ### 🔹 **Intermediate (Math & Logic Building)**
#
# Focus: Vectorization, broadcasting, masking, boolean indexing
#
# 7. **Create a 10x10 array with random values and find the min and max**
#
# 8. **Normalize a 5x5 random matrix**
#    (i.e., scale all values between 0 and 1)
#
# 9. **Multiply a 5x3 matrix by a 3x2 matrix (dot product)**
#    ➤ Confirm shape and result.
#
# 10. **Replace all odd numbers in an array with -1**
#
# 11. **Create a 2D array of shape (5,5) with 1 on the border and 0 inside**
#
# 12. **Given a 2D array, subtract the mean of each row**
#
# 13. **Create a checkerboard 8x8 matrix using slicing**
#
# 14. **How to convert a float array to integer without changing the shape?**
#
# ---
#
# ### 🔹 **Advanced (Machine Learning Logic Prep)**
#
# Focus: Vectorization logic, masks, performance-efficient ops
#
# 15. **Given a large matrix (1000x1000), find the row with the maximum sum**
#
# 16. **Generate a 2D Gaussian distribution matrix (10x10)**
#     ➤ Use `np.meshgrid` and `np.exp`
#
# 17. **Simulate a simple dataset with missing values (NaNs)**
#     ➤ Remove rows with NaNs or replace with column mean.
#
# 18. **Vectorize the following** (no loops allowed):
#     "Given an array of prices and discount%, compute the final prices"
#
# 19. **Given two matrices, identify where they differ (element-wise)**
#
# 20. **Perform Z-score normalization on a dataset matrix**
#
# 21. **Split a 1D array into N equal parts (e.g. N=4)**
#     ➤ Handle when it's not perfectly divisible.
#
# ---
#
# ### 🔹 **Bonus (Machine Learning Use-Case Simulation)**
#
# 22. **One-hot encode the following class labels**:
#     `labels = np.array([0, 2, 1, 3])`
#
# 23. **Simulate a simple dataset of shape (100, 3)**
#     ➤ Columns: height(cm), weight(kg), age
#     ➤ Normalize features column-wise.
#
# 24. **Simulate binary classification labels and predictions (0 or 1)**
#     ➤ Calculate accuracy, precision, recall using only NumPy.
#
# 25. **Given a covariance matrix, check if it's positive semi-definite**
