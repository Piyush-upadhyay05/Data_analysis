# %% [markdown]
# #### NumPy Learning Roadmap
#
# ## 1. Introduction to NumPy
# What is NumPy?
#
# Installation: pip install numpy
#
# Importing NumPy (import numpy as np)
#
# Differences between Python lists and NumPy arrays
#
# ## 2. NumPy Arrays (ndarray)
# Creating arrays using:
#
# np.array()
#
# np.zeros(), np.ones()
#
# np.arange(), np.linspace()
#
# np.eye() (identity matrix)
#
# np.random module
#
# Array data types (dtype)
#
# Array attributes: shape, ndim, size, itemsize, dtype, nbytes
#
#  ## 3. Array Indexing & Slicing
# 1D and 2D indexing
#
# Slicing arrays
#
# Boolean indexing
#
# Fancy indexing (using arrays of indices)
#
#  ## 4. Array Manipulation
# Reshaping: reshape(), ravel(), flatten()
#
# Transpose: .T
#
# Stacking arrays: hstack(), vstack(), concatenate()
#
# Splitting arrays: hsplit(), vsplit(), split()
#
# Adding/removing axes with np.newaxis or expand_dims()
#
# ## 5. Mathematical Operations
# Element-wise operations: +, -, *, /, **
#
# Aggregate functions: sum(), mean(), std(), min(), max(), argmax(), argmin()
#
# Axis-wise operations
#
# Broadcasting concept
#
# ## 6. Linear Algebra with NumPy
# Dot product: dot(), @
#
# Matrix multiplication: matmul()
#
# Determinant, Inverse: linalg.det(), linalg.inv()
#
# Eigenvalues and eigenvectors
#
# Solving linear equations: linalg.solve()
#
# ## 7. Random Module
# np.random.rand(), np.random.randn()
#
# np.random.randint()
#
# np.random.seed()
#
# Sampling: choice(), shuffle()
#
# ## 8. Handling Missing or Invalid Data
# Using np.nan, np.isnan(), np.isfinite()
#
# np.where() for conditional filtering
#
# Masked arrays
#
# ## 9. Advanced Topics
# Memory layout and performance tips
#
# Broadcasting rules (in-depth)
#
# Vectorization vs loops
#
# Structured arrays
#
# Universal Functions (ufuncs)
#
# ## 10. Practice & Projects
# Small projects:
#
# Matrix calculator
#
# Statistics dashboard
#
# Image manipulation using arrays
#
# Practice problems (Kaggle, LeetCode, NumPy docs)
